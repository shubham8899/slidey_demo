# %%
import pandas as pd
from pandasai import SmartDataframe
import seaborn

# %%
df = pd.read_csv('/Users/shubham/Documents/Slidey/supermarket_sales - Sheet1.csv')
df = df.sample(frac=1).reset_index(drop=True)
df = df[:100]

# %%
df
# Out:
#      Invoice ID Branch      City Customer type  Gender  \
# 0   453-33-6436      A    Yangon        Normal  Female
# 1   767-54-1907      B  Mandalay        Member  Female
# 2   531-80-1784      A    Yangon        Normal    Male
# 3   197-77-7132      B  Mandalay        Member    Male
# 4   420-18-8989      A    Yangon        Member  Female
# ..          ...    ...       ...           ...     ...
# 95  841-18-8232      B  Mandalay        Normal  Female
# 96  789-23-8625      B  Mandalay        Member    Male
# 97  868-06-0466      A    Yangon        Member    Male
# 98  503-21-4385      B  Mandalay        Member    Male
# 99  459-50-7686      A    Yangon        Normal  Female
#
#               Product line  Unit price  Quantity   Tax 5%     Total  \
# 0       Home and lifestyle       93.12         8  37.2480  782.2080
# 1      Fashion accessories       29.56         5   7.3900  155.1900
# 2   Electronic accessories       26.02         7   9.1070  191.2470
# ...

# %%
df.to_csv('sample_dataset.csv')

# %%
from pandasai.llm import OpenAI
llm = OpenAI(api_token="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", enable_cache=False)

# %%
df = SmartDataframe(df, config={"llm": llm, "enable_cache": False})

# %%
ans = df.chat('Histogram of payment types used in all sales')

# %%
type(ans)
# Out:
# NoneType

# %%
import streamlit as st
import pandas as pd
from pandasai import SmartDataframe
from io import StringIO
from pandasai.llm import OpenAI
import matplotlib 
import matplotlib.pyplot as plt
import PyQt6

matplotlib.use('Qt5Agg')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /Users/shubham/Documents/Slidey/test.ipynb Cell 9 line 1
#       <a href='vscode-notebook-cell:/Users/shubham/Documents/Slidey/test.ipynb#X21sZmlsZQ%3D%3D?line=6'>7</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell:/Users/shubham/Documents/Slidey/test.ipynb#X21sZmlsZQ%3D%3D?line=7'>8</a> import PyQt6
# ---> <a href='vscode-notebook-cell:/Users/shubham/Documents/Slidey/test.ipynb#X21sZmlsZQ%3D%3D?line=9'>10</a> matplotlib.use('Qt5Agg')
#
# File ~/Documents/Slidey/slidey/lib/python3.9/site-packages/matplotlib/__init__.py:1237, in use(backend, force)
#    1232 if plt is not None:
#    1233     try:
#    1234         # we need this import check here to re-raise if the
#    1235         # user does not have the libraries to support their
#    1236         # chosen backend installed.
# ...
